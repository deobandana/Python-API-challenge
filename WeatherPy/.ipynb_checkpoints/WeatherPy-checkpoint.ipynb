# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#enable jupyter extensions
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# jupyter nbextension enable --py widgetsnbextension
# !install gmaps 
# conda install -c conda-forge gmaps 

# enable gmaps
# !jupyter nbextension enable --py --sys-prefix gmaps
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
# install: missing destination file operand after 'gmaps'
# Try 'install --help' for more information.
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok

# %%
# Dependencies and Setup
import import_ipynb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = [-90, 90]
lng_range = [-180, 180]

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

cityName = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
maxTemp = []
windSpeed = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(-90.000,90.000, size=1500)
lngs = np.random.uniform(-180.000,180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count


len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

record=1
dataRecord = 1

print(f"Begining Data Retrieval")
print(f"......................")

for city in cities:
    try:
        response = requests.get(query_url + city).json() 
        cityName.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        maxTemp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        windSpeed.append(response["wind"]["speed"])
        cityRecord = response["name"]
        
        if dataRecord<51:
            record=dataRecord
            Set=1
        if dataRecord>50 and dataRecord<101:
            record=dataRecord-51
            Set=2
        if dataRecord>100 and dataRecord<151:
            record=dataRecord-101
            Set=3
        if dataRecord>150 and dataRecord<201:
            record=dataRecord-151
            Set=4
        if dataRecord>200 and dataRecord<251:
            record=dataRecord-201
            Set=5
        if dataRecord>250 and dataRecord<301:
            record=dataRecord-251
            Set=6
        if dataRecord>300 and dataRecord<351:
            record=dataRecord-301
            Set=7
        if dataRecord>350 and dataRecord<401:
            record=dataRecord-351
            Set=8
        if dataRecord>400 and dataRecord<451:
            record=dataRecord-401
            Set=9
        if dataRecord>450 and dataRecord<501:
            record=dataRecord-451
            Set=10
        if dataRecord>500 and dataRecord<551:
            record=dataRecord-501
            Set=11
        if dataRecord>550 and dataRecord<601:
            record=dataRecord-551
            Set=12
        if dataRecord>600 and dataRecord<651:
            record=dataRecord-601
            Set=13
        
        print(f"Processing Record {record} of Set {Set} | {cityRecord}")
        
        
        
        dataRecord= dataRecord + 1
        
        time.sleep(1.01)
    
    except:
        print("city not  found, Skipping.....")
    continue        
print(f"......................")
print(f"Data Retrieval Complete")
print(f"......................")
# Out:
# Begining Data Retrieval
# ......................
# Processing Record 1 of Set 1 | Punta Arenas
# Processing Record 2 of Set 1 | Port-Gentil
# Processing Record 3 of Set 1 | Saint-Philippe
# Processing Record 4 of Set 1 | Deputatsky
# Processing Record 5 of Set 1 | Rikitea
# Processing Record 6 of Set 1 | Tasiilaq
# Processing Record 7 of Set 1 | Thompson
# Processing Record 8 of Set 1 | Clyde River
# Processing Record 9 of Set 1 | Dorchester
# Processing Record 10 of Set 1 | Hirara
# Processing Record 11 of Set 1 | Matagami
# Processing Record 12 of Set 1 | Kruisfontein
# Processing Record 13 of Set 1 | Mataura
# Processing Record 14 of Set 1 | Barrow
# Processing Record 15 of Set 1 | Vao
# Processing Record 16 of Set 1 | Lüderitz
# Processing Record 17 of Set 1 | Dombås
# Processing Record 18 of Set 1 | Vysokogornyy
# Processing Record 19 of Set 1 | Port Alfred
# Processing Record 20 of Set 1 | Jamestown
# Processing Record 46 of Set 3 | Yumen
# Processing Record 47 of Set 3 | Maricá
# Processing Record 48 of Set 3 | Alekseyevka
# Processing Record 49 of Set 3 | Mareeba
# Processing Record 0 of Set 4 | Labuhan
# Processing Record 1 of Set 4 | Dandong
# Processing Record 2 of Set 4 | Norman Wells
# city not  found, Skipping.....
# Processing Record 3 of Set 4 | Najrān
# Processing Record 4 of Set 4 | Qaanaaq
# Processing Record 5 of Set 4 | Kumul
# Processing Record 6 of Set 4 | Narsaq
# Processing Record 7 of Set 4 | Gariāband
# Processing Record 8 of Set 4 | Olafsvik
# Processing Record 9 of Set 4 | Padre Bernardo
# Processing Record 10 of Set 4 | Oddur
# Processing Record 11 of Set 4 | Naze
# Processing Record 12 of Set 4 | Nhamundá
# Processing Record 13 of Set 4 | Port Keats
# Processing Record 14 of Set 4 | Monrovia
# Processing Record 15 of Set 4 | Humberto de Campos
# Processing Record 16 of Set 4 | Arraial do Cabo
# Processing Record 17 of Set 4 | Turaif
# Processing Record 18 of Set 4 | Mackay
# Processing Record 19 of Set 4 | Bosaso
# Processing Record 20 of Set 4 | Broome
# Processing Record 21 of Set 4 | Ribeira Grande
# Processing Record 22 of Set 4 | Puerto Baquerizo Moreno
# Processing Record 23 of Set 4 | Jacareacanga
# Processing Record 24 of Set 4 | Los Llanos de Aridane
# Processing Record 25 of Set 4 | Soyo
# Processing Record 26 of Set 4 | Torbay
# Processing Record 27 of Set 4 | Junín
# Processing Record 28 of Set 4 | Mikhaylovka
# Processing Record 29 of Set 4 | Preobrazheniye
# Processing Record 30 of Set 4 | Adrar
# Processing Record 31 of Set 4 | Westport
# Processing Record 32 of Set 4 | Rocha
# Processing Record 33 of Set 4 | Bouna
# Processing Record 34 of Set 4 | Chokurdakh
# city not  found, Skipping.....
# city not  found, Skipping.....
# city not  found, Skipping.....
# Processing Record 35 of Set 4 | Alcúdia
# Processing Record 36 of Set 4 | Pangnirtung
# Processing Record 37 of Set 4 | Porto Velho
# Processing Record 38 of Set 4 | Kharp
# Processing Record 39 of Set 4 | Abay
# Processing Record 40 of Set 4 | Pevek
# Processing Record 41 of Set 4 | Madison
# city not  found, Skipping.....
# Processing Record 42 of Set 4 | Coyhaique
# Processing Record 43 of Set 4 | Carutapera
# Processing Record 44 of Set 4 | Mahon
# Processing Record 45 of Set 4 | Hot Springs
# Processing Record 46 of Set 4 | Half Moon Bay
# Processing Record 47 of Set 4 | Yarmouth
# Processing Record 48 of Set 4 | Abu Kamal
# Processing Record 49 of Set 4 | Ranong
# Processing Record 0 of Set 5 | Toledo
# Processing Record 1 of Set 5 | Puerto Escondido
# Processing Record 2 of Set 5 | Kloulklubed
# city not  found, Skipping.....
# Processing Record 3 of Set 5 | Sing Buri
# Processing Record 4 of Set 5 | Lebu
# Processing Record 5 of Set 5 | Natchitoches
# Processing Record 6 of Set 5 | Balkanabat
# Processing Record 7 of Set 5 | Lata
# Processing Record 8 of Set 5 | Arrondissement de Pontivy
# Processing Record 9 of Set 5 | Saldanha
# Processing Record 10 of Set 5 | Sitka
# Processing Record 11 of Set 5 | Bilibino
# Processing Record 12 of Set 5 | Bubanza Province
# Processing Record 13 of Set 5 | Vostok
# Processing Record 14 of Set 5 | Hobyo
# Processing Record 15 of Set 5 | Masty
# Processing Record 16 of Set 5 | Skjervøy
# Processing Record 17 of Set 5 | Budogoshch'
# city not  found, Skipping.....
# Processing Record 18 of Set 5 | Dalvik
# Processing Record 19 of Set 5 | Verkh-Chebula
# Processing Record 20 of Set 5 | Yonezawa
# Processing Record 21 of Set 5 | Arrondissement de Muret
# Processing Record 22 of Set 5 | Faya
# Processing Record 23 of Set 5 | Katsuura
# Processing Record 24 of Set 5 | Bull Savanna
# Processing Record 25 of Set 5 | Souillac
# Processing Record 26 of Set 5 | Provideniya
# Processing Record 27 of Set 5 | Mizdah
# Processing Record 28 of Set 5 | Dolisie
# Processing Record 29 of Set 5 | Ola
# Processing Record 30 of Set 5 | Koster
# Processing Record 31 of Set 5 | Praia
# Processing Record 32 of Set 5 | Hasaki
# Processing Record 33 of Set 5 | Richards Bay
# Processing Record 34 of Set 5 | Bafoulabé
# Processing Record 35 of Set 5 | Ankazoabo
# Processing Record 36 of Set 5 | Ahipara
# Processing Record 37 of Set 5 | Saint-Pierre
# Processing Record 38 of Set 5 | Saint George
# Processing Record 39 of Set 5 | Auki
# Processing Record 40 of Set 5 | Forsytheganj
# city not  found, Skipping.....
# Processing Record 41 of Set 5 | Arman'
# Processing Record 42 of Set 5 | Osmeña
# Processing Record 43 of Set 5 | Sulphur Springs
# Processing Record 44 of Set 5 | Port Lincoln
# Processing Record 45 of Set 5 | Flinders
# Processing Record 46 of Set 5 | Isangel
# Processing Record 47 of Set 5 | Lagoa
# Processing Record 48 of Set 5 | Mehamn
# Processing Record 49 of Set 5 | Bjerkvik
# Processing Record 0 of Set 6 | Dunedin
# Processing Record 1 of Set 6 | Angra dos Reis
# city not  found, Skipping.....
# Processing Record 2 of Set 6 | Kabanjahe
# Processing Record 3 of Set 6 | Airai
# Processing Record 4 of Set 6 | Kollam
# Processing Record 5 of Set 6 | Bethel
# city not  found, Skipping.....
# Processing Record 6 of Set 6 | Vila Velha
# Processing Record 7 of Set 6 | Ituporanga
# Processing Record 8 of Set 6 | Babu
# city not  found, Skipping.....
# Processing Record 9 of Set 6 | Harbour Breton
# Processing Record 10 of Set 6 | Mozarlândia
# Processing Record 11 of Set 6 | Buala
# Processing Record 12 of Set 6 | Santa Isabel Rio Negro
# Processing Record 13 of Set 6 | Karasburg
# Processing Record 14 of Set 6 | Raudeberg
# Processing Record 15 of Set 6 | Verkhoyansk
# Processing Record 16 of Set 6 | Hastings
# Processing Record 17 of Set 6 | Kudahuvadhoo
# Processing Record 18 of Set 6 | San Patricio
# Processing Record 19 of Set 6 | Praia
# Processing Record 20 of Set 6 | Khasan
# Processing Record 21 of Set 6 | Bilma
# Processing Record 22 of Set 6 | Tacuarembó
# Processing Record 23 of Set 6 | Winneba
# city not  found, Skipping.....
# Processing Record 24 of Set 6 | Mariakani
# Processing Record 25 of Set 6 | Aykhal
# city not  found, Skipping.....
# Processing Record 26 of Set 6 | Durgapur
# Processing Record 27 of Set 6 | Ossora
# Processing Record 28 of Set 6 | Derzhavīnsk
# city not  found, Skipping.....
# Processing Record 29 of Set 6 | Banjar
# Processing Record 30 of Set 6 | Ciudad Bolivar
# city not  found, Skipping.....
# city not  found, Skipping.....
# Processing Record 31 of Set 6 | Ishigaki
# Processing Record 32 of Set 6 | Havelock
# Processing Record 33 of Set 6 | Ginda
# Processing Record 34 of Set 6 | Abhā
# Processing Record 35 of Set 6 | Ust'-Ilimsk
# Processing Record 36 of Set 6 | Yurga
# Processing Record 37 of Set 6 | Mariveles
# Processing Record 38 of Set 6 | Chernyshevskiy
# Processing Record 39 of Set 6 | Laas
# city not  found, Skipping.....
# city not  found, Skipping.....
# Processing Record 40 of Set 6 | Dolores
# Processing Record 41 of Set 6 | Scarborough
# Processing Record 42 of Set 6 | Santa Maria da Boa Vista
# Processing Record 43 of Set 6 | Chapais
# Processing Record 44 of Set 6 | Vardø
# Processing Record 45 of Set 6 | Verkhnyaya Inta
# Processing Record 46 of Set 6 | Gao
# Processing Record 47 of Set 6 | Bathsheba
# city not  found, Skipping.....
# city not  found, Skipping.....
# Processing Record 48 of Set 6 | Dayong
# Processing Record 49 of Set 6 | Safranbolu
# Processing Record 0 of Set 7 | Mitsamiouli
# Processing Record 1 of Set 7 | Malbork
# Processing Record 2 of Set 7 | Ulladulla
# Processing Record 3 of Set 7 | Carbonia
# Processing Record 4 of Set 7 | Port Augusta
# Processing Record 5 of Set 7 | Bousso
# Processing Record 6 of Set 7 | Tateyama
# Processing Record 7 of Set 7 | Namtsy
# Processing Record 8 of Set 7 | Hay River
# Processing Record 9 of Set 7 | Mutare
# Processing Record 10 of Set 7 | Yermekeyevo
# Processing Record 11 of Set 7 | Harper
# Processing Record 12 of Set 7 | Iquitos
# Processing Record 13 of Set 7 | Bianzhuang
# Processing Record 14 of Set 7 | Ancud
# city not  found, Skipping.....
# Processing Record 15 of Set 7 | Necochea
# Processing Record 16 of Set 7 | Puerto del Rosario
# Processing Record 17 of Set 7 | Belaya Gora
# Processing Record 18 of Set 7 | Tiksi
# Processing Record 19 of Set 7 | Barra Patuca
# Processing Record 20 of Set 7 | Batagay
# Processing Record 21 of Set 7 | Nouadhibou
# Processing Record 22 of Set 7 | Ust'-Koksa
# Processing Record 23 of Set 7 | Semey
# Processing Record 24 of Set 7 | Trat
# Processing Record 25 of Set 7 | Samarai
# Processing Record 26 of Set 7 | Lhokseumawe
# Processing Record 27 of Set 7 | Maţāy
# Processing Record 28 of Set 7 | Baruun-Urt
# Processing Record 29 of Set 7 | Baghdad
# Processing Record 30 of Set 7 | Vitim
# Processing Record 31 of Set 7 | Kyren
# Processing Record 32 of Set 7 | Sirte
# Processing Record 7 of Set 10 | Tālīkota
# Processing Record 8 of Set 10 | Cairns
# Processing Record 9 of Set 10 | Comodoro Rivadavia
# Processing Record 10 of Set 10 | Gaoual
# Processing Record 11 of Set 10 | Kavaratti
# Processing Record 12 of Set 10 | Buraidah
# Processing Record 13 of Set 10 | West Point
# Processing Record 14 of Set 10 | Eureka
# Processing Record 15 of Set 10 | Niquelândia
# Processing Record 16 of Set 10 | Erzin
# Processing Record 17 of Set 10 | Kenai
# Processing Record 18 of Set 10 | Djambala
# city not  found, Skipping.....
# Processing Record 19 of Set 10 | Naila
# Processing Record 20 of Set 10 | Marabu
# Processing Record 21 of Set 10 | Malakal
# Processing Record 22 of Set 10 | Gondal
# Processing Record 23 of Set 10 | Longido
# Processing Record 24 of Set 10 | Kailua
# Processing Record 25 of Set 10 | Goundam
# Processing Record 26 of Set 10 | Bol
# Processing Record 27 of Set 10 | Waipawa
# Processing Record 28 of Set 10 | Morondava
# Processing Record 29 of Set 10 | Ust-Kuyga
# Processing Record 30 of Set 10 | Sinnamary
# Processing Record 31 of Set 10 | Chebenki
# Processing Record 32 of Set 10 | Deep River
# Processing Record 33 of Set 10 | Faanui
# Processing Record 34 of Set 10 | Omboué
# Processing Record 35 of Set 10 | Deniliquin
# Processing Record 36 of Set 10 | Trivandrum
# Processing Record 37 of Set 10 | Nantucket
# Processing Record 38 of Set 10 | Sobradinho
# Processing Record 39 of Set 10 | Port Angeles
# Processing Record 40 of Set 10 | Tamiahua
# Processing Record 41 of Set 10 | Inzhavino
# Processing Record 42 of Set 10 | Romitan
# Processing Record 43 of Set 10 | Bubaque
# Processing Record 44 of Set 10 | Gympie
# Processing Record 45 of Set 10 | Santa Fe
# Processing Record 46 of Set 10 | Talaya
# Processing Record 47 of Set 10 | Nuuk
# Processing Record 48 of Set 10 | Sept-Îles
# Processing Record 49 of Set 10 | Alegrete
# Processing Record 0 of Set 11 | Chekhov
# Processing Record 1 of Set 11 | Charleston
# Processing Record 2 of Set 11 | Taoudenni
# Processing Record 3 of Set 11 | Kiryat Gat
# Processing Record 4 of Set 11 | Kriel
# Processing Record 5 of Set 11 | Martinho Campos
# Processing Record 6 of Set 11 | Kyzyl-Suu
# Processing Record 7 of Set 11 | Lafiagi
# Processing Record 8 of Set 11 | Trairi
# Processing Record 9 of Set 11 | Kitoy
# Processing Record 10 of Set 11 | Arlit
# Processing Record 11 of Set 11 | Slave Lake
# Processing Record 12 of Set 11 | Kemisē
# Processing Record 13 of Set 11 | Verkhnevilyuysk
# Processing Record 14 of Set 11 | Sanjwal
# Processing Record 15 of Set 11 | Alofi
# Processing Record 16 of Set 11 | Sobolevo
# Processing Record 17 of Set 11 | Beïnamar
# Processing Record 18 of Set 11 | La Ronge
# Processing Record 19 of Set 11 | Kwang Binh
# Processing Record 20 of Set 11 | Hokitika
# Processing Record 21 of Set 11 | Moba
# Processing Record 22 of Set 11 | Waterloo
# Processing Record 23 of Set 11 | Quatre Cocos
# Processing Record 24 of Set 11 | Nanning
# city not  found, Skipping.....
# Processing Record 25 of Set 11 | Susa
# Processing Record 26 of Set 11 | Chazuta
# Processing Record 27 of Set 11 | Avon
# Processing Record 28 of Set 11 | Taloqan
# Processing Record 29 of Set 11 | Egvekinot
# Processing Record 30 of Set 11 | Inverurie
# Processing Record 31 of Set 11 | Kalbay
# Processing Record 32 of Set 11 | Quelimane
# Processing Record 33 of Set 11 | Sibolga
# Processing Record 34 of Set 11 | Kangaatsiaq
# Processing Record 35 of Set 11 | Ambon City
# Processing Record 36 of Set 11 | Rundu
# Processing Record 37 of Set 11 | Tokur
# Processing Record 38 of Set 11 | Asău
# Processing Record 39 of Set 11 | Sallanches
# Processing Record 40 of Set 11 | Luanda
# Processing Record 41 of Set 11 | Sulangan
# Processing Record 42 of Set 11 | Mitú
# Processing Record 43 of Set 11 | Constitución
# Processing Record 44 of Set 11 | Margate
# Processing Record 45 of Set 11 | Garoowe
# Processing Record 46 of Set 11 | Cayhagan
# ......................
# Data Retrieval Complete
# ......................

# %% [markdown]
# .
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": cityName,
    "Lat":lat, 
    "Lng":lng,
    "Max Temp": maxTemp,
    "Humidity": humidity,
    "Cloudiness":cloudiness,
    "Wind Speed":windSpeed,
    "Country":country,
    "Date":date,       
}
weather_data=pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          547
# Lat           547
# Lng           547
# Max Temp      547
# Humidity      547
# Cloudiness    547
# Wind Speed    547
# Country       547
# Date          547
# dtype: int64

# %%
weather_data
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Punta Arenas -53.15  -70.92     35.60        74          74
# 1       Port-Gentil  -0.72    8.78     74.35        86          60
# 2    Saint-Philippe -21.36   55.77     66.20        72          68
# 3        Deputatsky  69.30  139.90     54.41        70          95
# 4           Rikitea -23.12 -134.97     70.38        79           9
# ..              ...    ...     ...       ...       ...         ...
# 542            Mitú   1.20  -70.17     71.98        98         100
# 543    Constitución -35.33  -72.42     50.45        84         100
# 544         Margate  51.38    1.39     63.00        90         100
# 545         Garoowe   8.41   48.48     75.74        61          38
# 546        Cayhagan   9.67  122.43     84.74        71           0
#
#      Wind Speed Country        Date
# 0         14.99      CL  1595813940
# 1         14.03      GA  1595813941
# 2          4.70      RE  1595813660
# 3          5.61      RU  1595813944
# 4         19.42      PF  1595813945
# ..          ...     ...         ...
# 542        1.14      CO  1595814586
# 543        8.21      CL  1595814474
# 544        3.00      GB  1595814588
# 545       16.96      SO  1595814589
# 546        5.82      PH  1595814590
#
# [547 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
clean_city_data=weather_data.drop(weather_data[weather_data['Humidity'] > 100].index, inplace = False)
clean_city_data
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Punta Arenas -53.15  -70.92     35.60        74          74
# 1       Port-Gentil  -0.72    8.78     74.35        86          60
# 2    Saint-Philippe -21.36   55.77     66.20        72          68
# 3        Deputatsky  69.30  139.90     54.41        70          95
# 4           Rikitea -23.12 -134.97     70.38        79           9
# ..              ...    ...     ...       ...       ...         ...
# 542            Mitú   1.20  -70.17     71.98        98         100
# 543    Constitución -35.33  -72.42     50.45        84         100
# 544         Margate  51.38    1.39     63.00        90         100
# 545         Garoowe   8.41   48.48     75.74        61          38
# 546        Cayhagan   9.67  122.43     84.74        71           0
#
#      Wind Speed Country        Date
# 0         14.99      CL  1595813940
# 1         14.03      GA  1595813941
# 2          4.70      RE  1595813660
# 3          5.61      RU  1595813944
# 4         19.42      PF  1595813945
# ..          ...     ...         ...
# 542        1.14      CO  1595814586
# 543        8.21      CL  1595814474
# 544        3.00      GB  1595814588
# 545       16.96      SO  1595814589
# 546        5.82      PH  1595814590
#
# [547 rows x 9 columns]

# %%
clean_city_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  547.000000  547.000000  547.000000  547.000000  547.000000  547.000000
# mean    20.552102   20.428684   69.150969   72.226691   47.548446    7.533400
# std     33.427613   87.775072   13.544519   19.111581   40.503594    5.251229
# min    -54.800000 -179.170000   33.800000    1.000000    0.000000    0.160000
# 25%     -6.495000  -52.840000   59.000000   63.000000    1.000000    3.360000
# 50%     22.980000   25.950000   70.540000   76.000000   42.000000    5.990000
# 75%     49.690000   94.385000   80.370000   87.000000   90.000000   10.055000
# max     78.220000  178.420000  108.000000  100.000000  100.000000   33.330000
#
#                Date
# count  5.470000e+02
# mean   1.595814e+09
# std    2.113248e+02
# min    1.595814e+09
# 25%    1.595814e+09
# 50%    1.595814e+09
# 75%    1.595814e+09
# max    1.595815e+09

# %%
# Extract relevant fields from the data frame
# Export the City_Data into a csv
clean_city_data.to_csv('../output_data/clean_city_data.csv')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
hemiIndex = weather_data.set_index('City')

hemiLat = hemiIndex['Lat']
hemiMaxT = hemiIndex['Max Temp']
hemiHum = hemiIndex['Humidity']
hemiCl = hemiIndex['Cloudiness']
hemiWS = hemiIndex['Wind Speed']

# Scatter Plot
plt.scatter(hemiLat, hemiMaxT, marker="o", edgecolors="black")

plt.title("City Latitude vs. Max Temperature   (Date:07/26/2020)")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../output_data/temp_vs_temp_plot.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(hemiLat, hemiHum, marker="o", edgecolors="black")

plt.title("City Latitude vs. Humidity   (Date:07/26/2020) ")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.ylim(-20,200)

plt.savefig("../output_data/temp_vs_humidity_plot.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(hemiLat, hemiCl, marker="o", edgecolors="black")

plt.title("City Latitude vs. Cloudiness   (Date:07/26/2020)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.ylim(-10, 110)

plt.savefig("../output_data/temp_vs_cloud_plot.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(hemiLat, hemiWS, marker="o", edgecolors="black")

plt.title("City Latitude vs. Wind Speed   (Date:07/26/2020)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../output_data/temp_vs_windspeed_plot.png")

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
# Northern Hemisphere
nHemi = hemiIndex.loc[(hemiIndex["Lat"] > 0), :]
nHemiLat = nHemi['Lat']
nHemiMaxT = nHemi['Max Temp']
nHemiHum = nHemi['Humidity']
nHemiCl = nHemi['Cloudiness']
nHemiWS = nHemi ['Wind Speed']

# Southern Hemisphere
sHemi = hemiIndex.loc[(hemiIndex["Lat"] <= 0), :]
sHemiLat = sHemi['Lat']
sHemiMaxT = sHemi['Max Temp']
sHemiHum = sHemi['Humidity']
sHemiCl = sHemi['Cloudiness']
sHemiWS = sHemi ['Wind Speed']

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
n_mVl_slope, n_mVl_int, n_mVl_r, n_mVl_p, n_mVl_std_err = linregress(nHemiLat, nHemiMaxT)
n_mVl_fit = n_mVl_slope *nHemiLat + n_mVl_int
line_eq = "y = " + str(round(n_mVl_slope,2)) + "x + " + str(round(n_mVl_int,2))
plt.scatter(nHemiLat, nHemiMaxT)
plt.plot(nHemiLat,n_mVl_fit,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.ylim(0, 110)
plt.xlim(-2, 83)
plt.title("Northern Hemisphere \n Max Temp vs. Latitude Linear Regression\n (Date:07/26/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f"The r-squared is: {n_mVl_r}")

plt.savefig("../output_data/Max Temp vs. Latitude Linear Regression.png")

plt.show()
# Out:
# The r-squared is: -0.663201552508027

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
s_mVl_slope, s_mVl_int, s_mVl_r, s_mVl_p, s_mVl_std_err = linregress(sHemiLat, sHemiMaxT)
s_mVl_fit = s_mVl_slope *sHemiLat + s_mVl_int
line_eq = "y = " + str(round(s_mVl_slope,2)) + "x + " + str(round(s_mVl_int,2))
plt.scatter(sHemiLat, sHemiMaxT)
plt.plot(sHemiLat,s_mVl_fit,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.ylim(0, 100)
plt.xlim(-58, 3)
plt.title("Southern Hemisphere \n Max Temp vs. Latitude Linear Regression\n (Date:07/26/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f"The r-squared is: {s_mVl_r}")

plt.savefig("../output_data/SH - Max Temp vs. Latitude Linear Regression.png")

plt.show()
# Out:
# The r-squared is: 0.7589833033098822

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
n_hVl_slope, n_hVl_int, n_hVl_r, n_hVl_p, n_hVl_std_err = linregress(nHemiLat, nHemiHum)
n_hVl_fit = n_hVl_slope *nHemiLat + n_hVl_int
line_eq = "y = " + str(round(n_hVl_slope,2)) + "x + " + str(round(n_hVl_int,2))
plt.scatter(nHemiLat, nHemiHum)
plt.plot(nHemiLat,n_hVl_fit,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.ylim(0, 105)
plt.xlim(-2, 82)
plt.title("Northern Hemisphere \n Humidity (%) vs. Latitude Linear Regression\n (Date:07/26/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f"The r-squared is: {n_hVl_r}")

plt.savefig("../output_data/NH - Humidity vs. Latitude Linear Regression.png")

plt.show()
# Out:
# The r-squared is: -0.058183966989015054

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
s_hVl_slope, s_hVl_int, s_hVl_r, s_hVl_p, s_hVl_std_err = linregress(sHemiLat, sHemiHum)
s_hVl_fit = s_hVl_slope *sHemiLat + s_hVl_int
line_eq = "y = " + str(round(s_hVl_slope,2)) + "x + " + str(round(s_hVl_int,2))
plt.scatter(sHemiLat, sHemiHum)
plt.plot(sHemiLat,s_hVl_fit,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.ylim(-2, 105)
plt.xlim(-58, 2)
plt.title("Southern Hemisphere \n Humidity (%) vs. Latitude Linear Regression\n  (Date:07/26/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f"The r-squared is: {s_hVl_r}")

plt.savefig("../output_data/SH - Humidity vs. Latitude Linear Regression.png")

plt.show()
# Out:
# The r-squared is: -0.03642700954016273

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
n_cVl_slope, n_cVl_int, n_cVl_r, n_cVl_p, n_cVl_std_err = linregress(nHemiLat, nHemiCl)
n_cVl_fit = n_cVl_slope *nHemiLat + n_cVl_int
line_eq = "y = " + str(round(n_cVl_slope,2)) + "x + " + str(round(n_cVl_int,2))
plt.scatter(nHemiLat, nHemiCl)
plt.plot(nHemiLat,n_cVl_fit,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.ylim(-5, 105)
plt.xlim(-2, 82)
plt.title("Northern Hemisphere \n Cloudiness (%) vs. Latitude Linear Regression\n  (Date:07/26/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f"The r-squared is: {n_cVl_r}")

plt.savefig("../output_data/NH - Cloudiness vs. Latitude Linear Regression.png")

plt.show()
# Out:
# The r-squared is: -0.022038951832004536

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
s_cVl_slope, s_cVl_int, s_cVl_r, s_cVl_p, s_cVl_std_err = linregress(sHemiLat, sHemiCl)
s_cVl_fit = s_cVl_slope *sHemiLat + s_cVl_int
line_eq = "y = " + str(round(s_cVl_slope,2)) + "x + " + str(round(s_cVl_int,2))
plt.scatter(sHemiLat, sHemiCl)
plt.plot(sHemiLat,s_cVl_fit,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.ylim(-5, 105)
plt.xlim(-58, 3)
plt.title("Northern Hemisphere \n Cloudiness (%) vs. Latitude Linear Regression\n  (Date:07/26/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f"The r-squared is: {s_cVl_r}")

plt.savefig("../output_data/SH - Cloudiness vs. Latitude Linear Regression.png")

plt.show()
# Out:
# The r-squared is: -0.07774476887324237

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
n_hVl_slope, n_hVl_int, n_hVl_r, n_hVl_p, n_hVl_std_err = linregress(nHemiLat, nHemiWS)
n_hVl_fit = n_hVl_slope *nHemiLat + n_hVl_int
line_eq = "y = " + str(round(n_hVl_slope,2)) + "x + " + str(round(n_hVl_int,2))
plt.scatter(nHemiLat, nHemiWS)
plt.plot(nHemiLat,n_hVl_fit,"r-")
plt.annotate(line_eq,(6,25),fontsize=15,color="red")
plt.ylim(-2, 35)
plt.xlim(-2, 82)
plt.title("Northern Hemisphere \n Wind Speed (mph) vs. Latitude Linear Regression\n (Date:07/26/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f"The r-squared is: {n_hVl_r}")

plt.savefig("../output_data/NH - Wind Speed vs. Latitude Linear Regression.png")

plt.show()
# Out:
# The r-squared is: 0.06076731205587259

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
s_hVl_slope, s_hVl_int, s_hVl_r, s_hVl_p, s_hVl_std_err = linregress(sHemiLat, sHemiWS)
s_hVl_fit = s_hVl_slope *sHemiLat + s_hVl_int
line_eq = "y = " + str(round(s_hVl_slope,2)) + "x + " + str(round(s_hVl_int,2))
plt.scatter(sHemiLat, sHemiWS)
plt.plot(sHemiLat,s_hVl_fit,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.ylim(-3, 25)
plt.xlim(-58, 3)
plt.title("Southern Hemisphere \n Wind Speed (mph) vs. Latitude Linear Regression\n (Date:07/26/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f"The r-squared is: {s_hVl_r}")

plt.savefig("../output_data/SH - Wind Speed vs. Latitude Linear Regression.png")

plt.show()
# Out:
# The r-squared is: -0.15559490360849032
